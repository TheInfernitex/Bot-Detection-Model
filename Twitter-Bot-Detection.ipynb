# %%
# Install the required modules
# !pip install --user pandas numpy datetime
# Out:
# ...
#   Using cached pandas-2.2.3-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# ...
# Using cached pandas-2.2.3-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# ...

# %%
# Import the required modules
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
# Load dataset
df = pd.read_csv("bot_detection_data.csv")

print(f"Show 5 Rows of Dataset:{df.head()}")

print(f"\n The dataset consists of {df.shape[0]} rows and {df.shape[1]} columns.\n")

print(f"\n Columns in the Dataset: {df.columns.tolist()}")

print(f"\n Data Types of Columns: {df.dtypes}")

print(f"\n Missing Values in Each Column: {df.isnull().sum()}")

print(f"\n Dataset Statistics: {df.describe()} ")

print(f"\n Distribution of Bot Labels: {df["Bot Label"].value_counts()}")
# Out:
# Show 5 Rows of Dataset:   User ID        Username                                              Tweet  \
# 0   132131           flong  Station activity person against natural majori...
# 1   289683  hinesstephanie  Authority research natural life material staff...
# 2   779715      roberttran  Manage whose quickly especially foot none to g...
# 3   696168          pmason  Just cover eight opportunity strong policy which.
# 4   704441          noah87                      Animal sign six data good or.
#
#    Retweet Count  Mention Count  Follower Count  Verified  Bot Label  \
# 0             85              1            2353     False          1
# 1             55              5            9617      True          0
# 2              6              2            4363      True          0
# 3             54              5            2242      True          1
# 4             26              3            8438     False          1
#
#        Location           Created At            Hashtags
# ...

# %%
# Convert timestamps to datetime format
df['Created At'] = pd.to_datetime(df['Created At'], errors='coerce')

# Remove missing values
df.dropna(inplace=True)

# Cleaning tweets
def clean_text(text):
    text = re.sub(r"http\S+|www\S+", "", text)  # Remove URLs
    text = re.sub(r"@\w+", "", text)  # Remove mentions
    text = re.sub(r"#\w+", "", text)  # Remove hashtags
    return text.lower()

df["Cleaned Tweet"] = df["Tweet"].apply(clean_text)

# Encode 'Verified' col as 0 or 1
df['Verified'] = df['Verified'].astype(int)

print(f"\n Dataset after cleaning: {df.head()}")
# Out:
# ✅ Dataset after cleaning:
#    User ID        Username                                              Tweet  \
# 1   289683  hinesstephanie  Authority research natural life material staff...
# 2   779715      roberttran  Manage whose quickly especially foot none to g...
# 3   696168          pmason  Just cover eight opportunity strong policy which.
# 4   704441          noah87                      Animal sign six data good or.
# 5   570928         james00  See wonder travel this suffer less yard office...
#
#    Retweet Count  Mention Count  Follower Count  Verified  Bot Label  \
# 1             55              5            9617         1          0
# 2              6              2            4363         1          0
# 3             54              5            2242         1          1
# 4             26              3            8438         0          1
# 5             41              4            3792         1          1
#
# ...
